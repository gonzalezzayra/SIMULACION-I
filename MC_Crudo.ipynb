# %% [markdown]
# <a href="https://colab.research.google.com/github/gonzalezzayra/SIMULACION-I/blob/main/MC_Crudo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MC Crudo(Media Muestral)**

# %%
import numpy as np
import random as rd
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Definimos la función de la raiz de arctan(x)
def f(x):
  return np.sqrt(np.arctan(x))

# %%
#Generamos 10 números entre 0 y 1
x = np.linspace(0,1,10)
print(x)
# Out:
# [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556
#  0.66666667 0.77777778 0.88888889 1.        ]

# %%
y = f(x)
print(y)
# Out:
# [0.         0.3326518  0.46762051 0.5672306  0.64670266 0.71210849
#  0.76681328 0.81304561 0.85243319 0.88622693]

# %%
#Definir la función de Montecarlo Crudo
def montecarlo(n):
  sumatoria = 0 #contador
  for i in range(n):
    x = rd.random() #se produce un numero aleatorio
    sumatoria += f(x)
  return sumatoria/n #es la sumatoria entre n

# %%
#Tamaño de muestra
n = 10000

monte = montecarlo(n)

#Imprimir el tamaño de la muestra y el promedio/media
print("Con una muestra de", n , "se obtuvo", monte)
# Out:
# Con una muestra de 10000 se obtuvo 0.6279985242034061

# %% [markdown]
# Definimos el experimento

# %%
def experimento(m):
  lista = []
  for i in range(m):
    mont = montecarlo(i+1)
    lista.append(mont)
  return(lista)

# %%
l = experimento(1000)
#print(l)

#se crea un tabla con los valores del experimento
tabla = pd.DataFrame({'Experimento: ': l})

print(tabla.to_string(index=False))
# Out:
#  Experimento:
#       0.474913
#       0.739044
#       0.651142
#       0.714887
#       0.462064
#       0.482226
#       0.516968
#       0.757857
#       0.683335
#       0.678800
#       0.604287
#       0.663371
#       0.686729
#       0.605309
#       0.651330
#       0.686209
#       0.688175
#       0.577608
#       0.608772
#       0.657753
#       0.599372
#       0.528829
#       0.582480
#       0.662329
#       0.590974
#       0.649897
#       0.563498
#       0.659806
#       0.644230
#       0.628747
#       0.611314
#       0.633461
#       0.636644
#       0.629437
#       0.645634
#       0.650993
#       0.655681
#       0.638904
#       0.654115
#       0.617153
#       0.592100
#       0.616297
#       0.654503
#       0.616616
#       0.633255
#       0.587715
#       0.557836
#       0.600229
#       0.635809
#       0.629434
#       0.681522
#       0.660797
#       0.645902
#       0.683507
#       0.579295
#       0.598936
#       0.624938
# ...

# %%
#Grafica de Convergencia de Montecarlo Crudo
plt.plot(l,color="b")
plt.title("Convergencia de MC Crudo")
plt.xlabel("Tamaño de la Muestra")
plt.ylabel("Valor de la Media Muestral")
plt.grid(True)
plt.show()
